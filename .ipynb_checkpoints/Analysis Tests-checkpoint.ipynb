# %%
from lib import transient
import os
import matplotlib.pyplot as plt

# %%
tr = transient.Transient()

# %%
filepath = 'E:/data/RuCl3/_RAW/RuCl3/2017-04-20/'
files = os.listdir(filepath)

# %%
tr.import_file(filepath + files[4],key_parameter = 'temperature', description='none')
t0 = 110

tr.crop_time_scale()
tr.shift_time(t0)
tr.filter_low_pass(cutHigh=0.01)
tr.flip_trace()
tr.remove_DC_offset()
tr.flip_time()

ax1 = plt.plot(tr.time,tr.trace)
plt.show()
# Out:
# Imported RuCl3-Pr-0.15mW-Pu-18.0mW-T-300k-1kAVG.mat as RuCl3_none_None_K

# %%
tr.date
# Out:
# '2017-04-20-16.09.40'

# %%
tr.raw_time
# Out:
# array([  -0.81865948,   -0.82156379,   -0.82445452, ...,  128.97869492,
#         128.97332208,  128.96793582])

# %%
tr.filter_low_pass(cutHigh=0.05)

# %%
figure = plt.figure('testplot')
ax1 = plt.plot(tr.time,tr.trace)
plt.show()
